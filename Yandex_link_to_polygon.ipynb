# %% [markdown]
# ## Преобразование ссылки Яндекс Карт в координаты полигона

# %%
import pandas as pd
import re

# %%
df = pd.read_excel('Полигоны_НН.xlsx', sheet_name = 0)
pd.set_option('display.max_colwidth', None)
df
# Out:
#                      Район  \
# 0   Старый_Нижний_Новгород
# 1                 Высоково
# 2               Усиловский
# 3         Печёрская_Долина
# 4           Верхние_Печёры
# ..                     ...
# 73            Светлоярский
# 74   Комсомольский_посёлок
# 75         5-7_микрорайоны
# 76        Народный_посёлок
# 77       посёлок_Дубравный
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Ссылка_yandex
# ...

# %%
link = 'https://yandex.ru/maps/47/nizhny-novgorod/geo/komsomolskiy_posyolok/1508573167/?ll=43.831778%2C56.369000&rl=43.812674%2C56.369125~0.011821%2C0.001581~0.009209%2C-0.007951~-0.009353%2C-0.003767~-0.008449%2C0.005039~0.001765%2C0.000576&rlt=area&z=14.54'

cut = re.search(r'rl=(.*?)&rlt', link)                                       #с помощью рег выражения вырезаем часть строки между 2 метками
cut_link = cut.group(1)
coordinates_list = cut_link.split('~')                                       #делим по ~ на координаты

coordinates = []
first_latitude, first_longitude = coordinates_list[0].split('%2C') 
coordinates.append((float(first_longitude), float(first_latitude)))          #получаем координату начальной точки полигона и фиксируем ее в списке

previous_latitude = float(first_latitude)  
previous_longitude = float(first_longitude)

for i in range(1, len(coordinates_list)):
    delta_latitude, delta_longitude = coordinates_list[i].split('%2C')       #получаем значения дельты
    latitude = previous_latitude + float(delta_latitude)                     #получаем i-ое значение широты
    longitude = previous_longitude + float(delta_longitude)                  #получаем i-ое значение долготы
    latitude = round(latitude, 6)                                            #округляем до 6 знаков после точки (иначе точка уплывает...)
    longitude = round(longitude, 6)
    coordinates.append((float(longitude), float(latitude)))                  #записываем кортеж в список
    previous_latitude = latitude                                             #обновляем значения предыдущих широты и долготы
    previous_longitude = longitude

coordinates
# Out:
# [(56.369125, 43.812674),
#  (56.370706, 43.824495),
#  (56.362755, 43.833704),
#  (56.358988, 43.824351),
#  (56.364027, 43.815902),
#  (56.364603, 43.817667)]

# %% [markdown]
# ## Функция

# %%
import pandas as pd
import re

# %%
df = pd.read_excel('Полигоны_НН.xlsx', sheet_name = 0)

# %%
def coordinates_from_link(link):
    """
    Преобразует ссылку на полигон с Яндекс Карт в список тюплов вида [(Д, Ш), (Д, Ш), ..., (Д, Ш)]
    
    link - столбец со ссылкой на полигон с Яндекс Карт (полученная при помощи инструмента Планиметр)
    """
    cut = re.search(r'rl=(.*?)&rlt', link)                                              #с помощью рег выражения вырезаем часть строки между 2 метками
    cut_link = cut.group(1)
    coordinates_list = cut_link.split('~')                                              #делим по '~' на координаты
    
    coordinates = []
    first_latitude, first_longitude = coordinates_list[0].split('%2C') 
    coordinates.append((float(first_longitude), float(first_latitude)))                 #получаем координату начальной точки полигона и фиксируем ее в списке
    
    previous_latitude = float(first_latitude)  
    previous_longitude = float(first_longitude)
    
    for i in range(1, len(coordinates_list)):
        delta_latitude, delta_longitude = coordinates_list[i].split('%2C')              #получаем значения дельты
        latitude = previous_latitude + float(delta_latitude)                            #получаем i-ое значение широты
        longitude = previous_longitude + float(delta_longitude)                         #получаем i-ое значение долготы
        latitude = round(latitude, 6)                                                   #фиксируем округление до 6 знаков после точки (иначе точка уплывает...)
        longitude = round(longitude, 6)
        coordinates.append((float(longitude), float(latitude)))                         #записываем кортеж в список
        previous_latitude = latitude                                                    #обновляем значения предыдущих широты и долготы
        previous_longitude = longitude
    
    return coordinates

def polygon_yandex(dataf, polygon_name, link):
    """
    Для каждой ссылки в dataf по строкам преобразует ссылку в координаты и создает новый df со столбцами 'Район' и 'Координаты'
    
    dataf - DataFrame, из которого используются данные 
    polygon_name - столбец с названием района
    link - столбец со ссылкой на полигон с Яндекс Карт (полученная при помощи инструмента Планиметр) 
    """
    coordinates = []
    for index, row in dataf.iterrows():                                                 #итерируем по строкам dataf
        extracted_coordinates = coordinates_from_link(row[link])                        #применяем 1 функцию
        coordinates.append(extracted_coordinates)
    df_1 = pd.DataFrame({'Район': dataf[polygon_name], 'Координаты': coordinates})
    return df_1

# %%
df_1 = polygon_yandex(
                                   dataf = df, 
                                   polygon_name = 'Район',
                                   link = 'Ссылка_yandex',
                                  )

# %%
df_1
# Out:
#                      Район  \
# 0   Старый_Нижний_Новгород
# 1                 Высоково
# 2               Усиловский
# 3         Печёрская_Долина
# 4           Верхние_Печёры
# ..                     ...
# 73            Светлоярский
# 74   Комсомольский_посёлок
# 75         5-7_микрорайоны
# 76        Народный_посёлок
# 77       посёлок_Дубравный
#
#                                                                                                                                                                                                                                                                                                                                                                                          Координаты
# ...

# %%
#Сохраняем в Excel
writer = pd.ExcelWriter('Координаты_НН.xlsx')
df_1.to_excel(writer)
writer.save()

# %% [markdown]
# # Береговая линия Владивосток

# %%
df = pd.read_excel('Береговая_линия.xlsx', sheet_name = 1)
df
# Out:
#                                             Западное  \
# 0  https://yandex.ru/maps/geo/vladivostok/5306769...
# 1  https://yandex.ru/maps/geo/vladivostok/5306769...
# 2  https://yandex.ru/maps/geo/vladivostok/5306769...
# 3  https://yandex.ru/maps/geo/vladivostok/5306769...
# 4  https://yandex.ru/maps/geo/vladivostok/5306769...
#
#                                                Южное  \
# 0  https://yandex.ru/maps/geo/vladivostok/5306769...
# 1  https://yandex.ru/maps/geo/vladivostok/5306769...
# 2  https://yandex.ru/maps/geo/vladivostok/5306769...
# 3                                                  1
# 4                                                  1
#
#                                            Восточное
# 0  https://yandex.ru/maps/geo/vladivostok/5306769...
# 1  https://yandex.ru/maps/geo/vladivostok/5306769...
# 2                                                  1
# 3                                                  1
# 4                                                  1

# %%
str(df['Западное'][0])
# Out:
# 'https://yandex.ru/maps/geo/vladivostok/53067690/?l=sat%2Cskl&ll=131.934456%2C43.123941&rl=131.841068%2C43.078456~0.000408%2C0.001919~0.000901%2C0.001636~0.003111%2C0.001856~0.001309%2C0.001824~0.001506%2C0.002180~0.002169%2C0.000539~0.002730%2C0.000999~0.001030%2C0.001535~0.000054%2C0.001282~0.001276%2C0.003030~0.002478%2C0.000553~0.000822%2C0.002226~0.001514%2C0.005260~0.004727%2C0.001471~0.003464%2C0.000794~0.001706%2C0.000601~0.001540%2C0.001073~0.000054%2C0.001854~-0.000888%2C0.001603~-0.001217%2C0.002893~0.003362%2C0.000866~0.001307%2C0.000848~0.000663%2C0.000633~0.000510%2C0.000424~0.000656%2C0.000553~0.001000%2C0.000768~0.000117%2C0.000481~-0.000131%2C0.000635~-0.001318%2C0.001228~-0.001183%2C0.001029~0.000030%2C0.001017~0.000279%2C0.000938~0.000325%2C0.001126~0.000261%2C0.000987~0.000482%2C0.001562&z=13'

# %%
link = str(df['Восточное'][1])

cut = re.search(r'rl=(.*?)&z', link)                                       #с помощью рег выражения вырезаем часть строки между 2 метками
cut_link = cut.group(1)
coordinates_list = cut_link.split('~')                                       #делим по ~ на координаты

coordinates = []
first_latitude, first_longitude = coordinates_list[0].split('%2C') 
coordinates.append((float(first_longitude), float(first_latitude)))          #получаем координату начальной точки полигона и фиксируем ее в списке

previous_latitude = float(first_latitude)  
previous_longitude = float(first_longitude)

for i in range(1, len(coordinates_list)):
    delta_latitude, delta_longitude = coordinates_list[i].split('%2C')       #получаем значения дельты
    latitude = previous_latitude + float(delta_latitude)                     #получаем i-ое значение широты
    longitude = previous_longitude + float(delta_longitude)                  #получаем i-ое значение долготы
    latitude = round(latitude, 6)                                            #округляем до 6 знаков после точки (иначе точка уплывает...)
    longitude = round(longitude, 6)
    coordinates.append((float(longitude), float(latitude)))                  #записываем кортеж в список
              (43.150607, 132.066377), (43.151996, 132.060884), (43.147283, 132.057022), (43.145303, 132.055777), (43.144046, 132.054532), (43.142349, 132.053459),
              (43.139961, 132.050584), (43.134084, 132.046979), (43.131808, 132.043563), (43.130142, 132.043134), (43.127879, 132.040988), (43.125301, 132.039186),
              (43.123415, 132.036826), (43.121466, 132.032251), (43.118982, 132.033624), (43.117159, 132.030749), (43.117112, 132.028024), (43.116735, 132.026093),
              (43.116028, 132.024301), (43.115368, 132.023067), (43.114079, 132.022241), (43.113392, 132.020348), (43.115381, 132.01832), (43.115436, 132.016485),
              (43.11524, 132.014811), (43.115114, 132.013105), (43.114499, 132.011663), (43.11119, 132.009871), (43.108514, 132.009768), (43.106502, 132.008416),
              (43.104867, 132.006099), (43.10338, 132.001915), (43.102044, 131.998031), (43.100641, 131.994422), (43.09737, 131.993478), (43.095816, 131.992489),
              (43.094665, 131.990388), (43.093681, 131.989182), (43.092778, 131.987641), (43.091829, 131.986408), (43.091394, 131.984036), (43.090952, 131.982548),
              (43.090398, 131.981123), (43.089712, 131.980064), (43.089189, 131.97836), (43.089001, 131.976753)]
}

# %%
west_coast = pd.DataFrame(coast_line['west_coast'], columns = ['Широта', 'Долгота'])
west_coast['coast'] = ['west_coast'] * len(west_coast)

south_coast = pd.DataFrame(coast_line['south_coast'], columns = ['Широта', 'Долгота'])
south_coast['coast'] = ['south_coast'] * len(south_coast)

east_coast = pd.DataFrame(coast_line['east_coast'], columns = ['Широта', 'Долгота'])
east_coast['coast'] = ['east_coast'] * len(east_coast)

# %%
east_coast
# Out:
#        Широта     Долгота       coast
# 0   43.217223  132.183139  east_coast
# 1   43.216925  132.181133  east_coast
# 2   43.216643  132.178386  east_coast
# 3   43.216345  132.176358  east_coast
# 4   43.216008  132.174942  east_coast
# ..        ...         ...         ...
# 95  43.090952  131.982548  east_coast
# 96  43.090398  131.981123  east_coast
# 97  43.089712  131.980064  east_coast
# 98  43.089189  131.978360  east_coast
# 99  43.089001  131.976753  east_coast
#
# [100 rows x 3 columns]

# %%
all_coast = pd.concat([west_coast, south_coast, east_coast])
all_coast
# Out:
#        Широта     Долгота       coast
# 0   43.078456  131.841068  west_coast
# 1   43.080375  131.841476  west_coast
# 2   43.082011  131.842377  west_coast
# 3   43.083867  131.845488  west_coast
# 4   43.085691  131.846797  west_coast
# ..        ...         ...         ...
# 95  43.090952  131.982548  east_coast
# 96  43.090398  131.981123  east_coast
# 97  43.089712  131.980064  east_coast
# 98  43.089189  131.978360  east_coast
# 99  43.089001  131.976753  east_coast
#
# [352 rows x 3 columns]

# %%
all_coast['coast'].unique()
# Out:
# array(['west_coast', 'south_coast', 'east_coast'], dtype=object)

# %%
#Сохраняем в Excel
writer = pd.ExcelWriter('Береговая_линия_2.xlsx')
all_coast.to_excel(writer)
writer.save()
