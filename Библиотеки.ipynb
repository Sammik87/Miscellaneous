# %%
#Перед тем как ставить последний Python, необходимо убедиться в том, что важные библиотеки на нем полетят!

#!pip install pandas                #работа с таблицами
#!pip install openpyxl              #необходим для Excel
#!pip install camelot-py            #работа с pdf
#!pip install numpy                 #работа с массивами
#!pip install seaborn               #графики
#!pip install matplotlib            #графики
#!pip install plotly                #графики

#!pip install adtk                  #нужен для работы функций

#!pip install geopy                 #география, карты
#!pip install folium                #география, карты
#!pip install osmnx                 #география, карты
#!pip install geopandas             #география, карты

#!pip install openstreetmap         #география, карты, для установки нужен lxml
#!pip install --upgrade lxml

#!pip install keras                 #нейронные сети
#!pip install tensorflow            #нейронные сети, для версии Python до 3.12
#!pip install tensorflow-cpu
#!pip install tensorflow-directml   #только для Python x86-64 3.5, 3.6, or 3.7, https://github.com/microsoft/tensorflow-directml?ysclid=m7uxpuzwzd407014208
#!pip install tf-nightly            #нейронные сети, для версии Python до 3.12
#!pip install transformers          #LLM, Bert

#!pip install scikit-learn          #моделирование и прочие статистические инструменты
#!pip install imbalanced-learn      #статистические инструменты
#!pip install scipy                 #статистические инструменты
#!pip install pydotplus             #отображает дерево решений

#!pip install tqdm                  #полоса прогресса
#!pip install PyPrind               #полоса прогресса

#!pip install optuna                #оптимизация гиперпараметров

#!pip install catboost              #бустинг, версии Python до 3.12
#!pip install ipywidgets            #widget
#!pip install conan
#!pip install wheel
#jupyter nbextension enable --py widgetsnbextension

#!pip install xgboost               #бустинг
#!pip install lightgbm              #бустинг

#!pip install shap                  #интерпретация ML моделей, для версии Python до 3.12
#!pip install pdpbox                #интерпретация ML
#!pip install lime                  #интерпретация ML
#!pip install yellowbrick           #интерпретация ML
#!pip install alibi[ray]            #ускоряет поиск alibi
#!pip install alibi                 #интерпретация ML
#!pip install eli5                  #интерпретация ML, объясни, как будто мне 5
#!pip install interpret-core        #интерпретация ML для GAM
#!pip install skater                #интерпретация ML
#!pip install skope-rules           #интерпретация ML
#!pip install witwidget             #интерпретация ML, которые используют сценарий "что, если"

#!pip install pillow                #работа с картинками
#!pip install opencv-python         #работа с картинками

#!pip install split-folders         #разбивает данные для обучения, валидации и теста

#!pip install selenium              #парсинг
#!pip install selenium-stealth      #парсинг
#!pip install beautifulsoup4        #парсинг

#!pip install pygam                 #эконометрические модели
#!pip install statsmodels           #эконометрические модели
#!pip install fbprophet             #эконометрические модели
#!pip install spatially-explicit    #географически взвешенная регрессия (ГВР)
#!pip install mgwr                  #географически взвешенная регрессия (ГВР)
#!pip install pmdarima              #эконометрические модели, временные ряды
#!pip install prophet               #временные ряды, библиотека от Facebook

#!pip install pyod                  #работа с выбросами + pip install --upgrade pyod
#!pip install pygod                 #работа с выбросами
#!pip install torch                 #нужен для pyod

#!pip install jupyterlab-mathjax3

#!pip install evidently             #интерпретация классификации
#!pip install phik                  #корреляция

#!pip install streamlit             #развертывание моделей

#!pip install pymorphy3             #работа с текстом, pymorphy2 - больше не работает
#!pip install nltk                  #работа с текстом
#!pip install natasha               #работа с текстом
#!pip install pymystem3             #работа с текстом
#!pip install spacy                 #работа с текстом
#!pip install textblob              #работа с текстом

#difflib                            #сходство векторов, текст
#!pip install fuzzywuzzy            #сходство векторов, текст
#!pip install RapidFuzz             #сходство векторов, текст

#!pip install vecstack              #stacking
#!pip install mlxtend               #stacking
#!pip install mlens                 #stacking

#!pip install kneed                 #метод локтя

#!pip install PyWavelets            #вейвлет-анализа

#!pip install deap                  #генетические алгоритмы
#!pip install gudhi                 #топологический анализ данных (TDA)

#!pip install -U g4f[all]           #чат GPT4

#!pip install streamlit-folium      #разработка карт
#!pip install streamlit             #web приложения
#!pip install customtkinter         #разработка
#!pip install tk                    #разработка tkinter

#!pip install qiskit[all]           #квантовые алгоритмы
#!pip install qiskit-aer            #квантовые алгоритмы
#!pip install qiskit-machine-learning #квантовые алгоритмы
#!pip install qiskit-algorithms     #квантовые алгоритмы
#!pip install PennyLane             #квантовые алгоритмы

#!pip install ipython_sql           #использования SQL magic commands в Jupyter
#!pip install sql-magic
#!pip install psycopg2-binary       #Рекомендуется для упрощения установки

# C:\Users\user\AppData\Local\Programs\Python\Python312\python.exe -m pip install psycopg2-binary

#python.exe -m pip install --upgrade pip      #обновление pip
#pip install --upgrade pyod

#!pip uninstall numpy                         #удаление библиотеки
#!pip install --force-reinstall numpy==1.26.4  #переустановка библиотки нужной версии, 1.26.4, 2.0.0
# Out:
# ^C
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027536B26990>, 'Connection to files.pythonhosted.org timed out. (connect timeout=15)')': /packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
# ...

# %%
import csv
import random
import pickle

from time import sleep
import winsound
import requests
import datetime

import seaborn as sns

import math
import pylab
import locale
import difflib

# %matplotlib inline
sns.set()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np

# %%
np.__version__
# Out:
# '1.26.4'

# %%
import natasha

print(dir(natasha))
# Out:
# ['AddrExtractor', 'DatesExtractor', 'Doc', 'LOC', 'MoneyExtractor', 'MorphVocab', 'NamesExtractor', 'NewsEmbedding', 'NewsMorphTagger', 'NewsNERTagger', 'NewsSyntaxParser', 'ORG', 'PER', 'Segmenter', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'const', 'data', 'doc', 'emb', 'extractors', 'morph', 'ner', 'norm', 'obj', 'record', 'segment', 'shape', 'span', 'syntax']

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       2.1.0
# adtk                          0.6.2
# aiohappyeyeballs              2.4.6
# aiohttp                       3.11.13
# aiohttp_socks                 0.10.1
# aiosignal                     1.3.2
# alabaster                     1.0.0
# alembic                       1.14.1
# alibi                         0.9.6
# altair                        5.5.0
# annotated-types               0.7.0
# anyio                         4.8.0
# appdirs                       1.4.4
# argon2-cffi                   23.1.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.3.0
# asttokens                     3.0.0
# astunparse                    1.6.3
# async-lru                     2.0.4
# attrs                         23.2.0
# babel                         2.17.0
# beautifulsoup4                4.13.3
# bleach                        6.2.0
# ...

# %%
import os
import sys
os.path.dirname(sys.executable)
# Out:
# 'C:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python312'

# %%
C:\Users\user\AppData\Local\Programs\Python\Python312\python.exe

# %%
import sys

is_64bits = sys.maxsize > 2**32
print(is_64bits)

if is_64bits:
    print('Python is running as 64-bit application')
else:
    print('Python is running as 32-bit application')
# Out:
# True
# Python is running as 64-bit application

# %%
# Посмотреть версию Python в cmd
python --version

# %%
#Переход в нужный каталог
cd C:\!JN\Python37
